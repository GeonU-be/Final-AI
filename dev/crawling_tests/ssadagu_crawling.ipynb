# %%
# Cell 1: 필수 라이브러리 및 Playwright 브라우저 설치
# 실행 환경에 Playwright와 pandas가 설치되어 있지 않다면 아래 셀을 먼저 실행하세요.
# %pip install playwright pandas
# !playwright install chromium
# Out:
# Requirement already satisfied: playwright in c:\anaconda\envs\rag_chatbot\lib\site-packages (1.56.0)
# Requirement already satisfied: pandas in c:\anaconda\envs\rag_chatbot\lib\site-packages (2.3.3)
# Requirement already satisfied: pyee<14,>=13 in c:\anaconda\envs\rag_chatbot\lib\site-packages (from playwright) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in c:\anaconda\envs\rag_chatbot\lib\site-packages (from playwright) (3.1.1)
# Requirement already satisfied: typing-extensions in c:\anaconda\envs\rag_chatbot\lib\site-packages (from pyee<14,>=13->playwright) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\anaconda\envs\rag_chatbot\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\envs\rag_chatbot\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\envs\rag_chatbot\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda\envs\rag_chatbot\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\anaconda\envs\rag_chatbot\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Cell 2: 라이브러리 import 및 설정
import sys
import tempfile
import subprocess
import os
import json
import re
import inspect
from urllib.parse import quote

# 노트북에서 시각 디버깅을 원하면 False로 설정하세요
NOTEBOOK_HEADLESS = True

# 검색할 키워드 입력 (여기를 수정하세요)
SEARCH_KEYWORD = "컴퓨터"  # 예시: "여성 티셔츠", "노트북", "스마트폰" 등

# 최대 수집할 상품 개수
MAX_PRODUCTS = 30

# 검색 URL 생성
search_url = f"https://ssadagu.kr/shop/search.php?ss_tx={quote(SEARCH_KEYWORD)}"

print(f"🔍 검색 키워드: {SEARCH_KEYWORD}")
print(f"🔗 검색 URL: {search_url}")
print(f"📦 최대 수집 개수: {MAX_PRODUCTS}개\n")
# Out:
# 🔍 검색 키워드: 컴퓨터
# 🔗 검색 URL: https://ssadagu.kr/shop/search.php?ss_tx=%EC%BB%B4%ED%93%A8%ED%84%B0
# 📦 최대 수집 개수: 30개

# %%
# Cell 3: 크롤링 함수 정의

def crawl_ssadagu_products(headless=True, search_url="", max_products=30, search_keyword=""):
    """
    싸다구 쇼핑몰에서 상품을 크롤링합니다.
    
    Args:
        headless: 헤드리스 모드 여부
        search_url: 검색 URL
        max_products: 최대 수집할 상품 개수
        search_keyword: 검색 키워드
        
    Returns:
        dict: 크롤링 결과 딕셔너리
    """
    from playwright.sync_api import sync_playwright
    import json
    import time
    import re
    
    products = []
    
    def extract_price_from_detail(detail_page):
        selectors = [
            "div.item-info div.item-info-base div.flex-container div.flex-container h3.pdt_price span.price.gsItemPriceKWR",
            "div.item-info div.item-info-base h3.pdt_price span.price",
            "div.item-info-base .pdt_price span[class*='price']",
            "span.price.gsItemPriceKWR",
            ".pdt_price span.price"
        ]
        for selector in selectors:
            try:
                price_elem = detail_page.query_selector(selector)
                if price_elem:
                    price_text = price_elem.inner_text().strip()
                    if not price_text:
                        continue
                    price_match = re.search(r'([\d,]+)', price_text)
                    if price_match:
                        raw_value = price_match.group(1)
                        normalized = raw_value.replace(',', '')
                        if normalized.isdigit():
                            formatted = "{:,}원".format(int(normalized))
                            return formatted
                    if "원" in price_text:
                        return price_text
            except Exception:
                continue
        return ""
    
    def extract_detail_specs(detail_page):
        specs = {}
        try:
            container = detail_page.query_selector("div.pro-info-boxs") or detail_page.query_selector("#productAttributes")
            if not container:
                return specs
            items = container.query_selector_all("div.pro-info-item")
            for item in items:
                try:
                    title_elem = item.query_selector("div.pro-info-title") or item.query_selector("div[class*='pro-info-title']")
                    value_elem = item.query_selector("div.pro-info-info") or item.query_selector("div[class*='pro-info-info']")
                    if not title_elem or not value_elem:
                        continue
                    title = title_elem.inner_text().strip().rstrip(":")
                    value = value_elem.inner_text().strip()
                    if title and value:
                        specs[title] = value
                except Exception:
                    continue
        except Exception:
            pass
        return specs
    
    with sync_playwright() as p:
        browser = p.chromium.launch(headless=headless)
        page = browser.new_page()
        
        print(f"접속 중: {search_url}")
        try:
            page.goto(search_url, wait_until="networkidle", timeout=30000)
            time.sleep(2)
            
            # 스크롤하여 동적 콘텐츠 로드 (더 많은 상품 로드)
            for scroll_idx in range(5):
                page.evaluate("window.scrollBy(0, window.innerHeight)")
                time.sleep(0.8)
            
            # 페이지 끝까지 스크롤
            page.evaluate("window.scrollTo(0, document.body.scrollHeight)")
            time.sleep(1)
            
            # 상품 리스트 찾기
            product_list = page.query_selector("ul.search_product_list")
            if not product_list:
                product_list = page.query_selector("#div_product_list")
            
            if product_list:
                # 각 상품 li 요소 찾기
                product_items = product_list.query_selector_all("li")
                print(f"\n발견된 상품 수: {len(product_items)}개")
                
                # 유효한 상품이 max_products개가 될 때까지 더 많은 상품 처리
                processed_count = 0
                for item_elem in product_items:
                    if len(products) >= max_products:
                        break
                    processed_count += 1
                    try:
                        # data 속성에서 정보 추출
                        title = item_elem.get_attribute("data-title") or ""
                        img_url = item_elem.get_attribute("data-img-url") or ""
                        
                        # 상품명 정제 (쉼표, 백슬래시, 큰따옴표 이후 불필요한 정보 제거)
                        if title:
                            # 큰따옴표로 둘러싸인 부분 제거 (이스케이프된 큰따옴표 포함)
                            title = re.sub(r'\\"[^"]*\\"', '', title).strip()
                            title = re.sub(r'"[^"]*"', '', title).strip()
                            # 백슬래시가 있으면 그 뒤 부분 제거
                            if "\\" in title:
                                title = title.split("\\")[0].strip()
                            # 쉼표로 분리하여 첫 번째 부분만 사용 (주요 상품명)
                            if "," in title:
                                title = title.split(",")[0].strip()
                            # 또는 특정 키워드 이후 제거
                            keywords_to_remove = [
                                "모든 네트워크 지원",
                                "심천 휴대폰 시장",
                                "공장 도매",
                                "인기 상품",
                                "도매",
                                "공장"
                            ]
                            for keyword in keywords_to_remove:
                                if keyword in title:
                                    idx = title.find(keyword)
                                    title = title[:idx].strip()
                                    break
                        
                        # 상품 링크 찾기
                        product_link = ""
                        link_elem = item_elem.query_selector("a")
                        if link_elem:
                            href = link_elem.get_attribute("href") or ""
                            if href:
                                if href.startswith("http"):
                                    product_link = href
                                else:
                                    product_link = "https://ssadagu.kr" + href
                        
                        # 상품 상세 페이지에서 정확한 가격 및 상세 정보 추출
                        price = ""
                        detail_specs = {}
                        if product_link:
                            detail_page = None
                            try:
                                detail_page = browser.new_page()
                                detail_page.goto(product_link, wait_until="domcontentloaded", timeout=30000)
                                # 요청 간 더 긴 대기 시간을 주어 rate limiting 가능성을 낮춤
                                time.sleep(2.0 + (processed_count % 3))  # 2~4초 사이 대기
                                detail_page.wait_for_selector("div.item-info-base", timeout=5000)
                                price = extract_price_from_detail(detail_page)
                                detail_specs = extract_detail_specs(detail_page)
                            except Exception as detail_error:
                                print(f"  상품 {processed_count} 상세 정보 추출 실패: {detail_error}")
                            finally:
                                if detail_page:
                                    try:
                                        detail_page.close()
                                    except Exception:
                                        pass
                        
                        # 최소한 제목이 있어야 유효한 상품
                        if title:
                            product_data = {
                                "title": title,
                                "price": price,
                                "product_link": product_link,
                                "thumbnail_url": img_url,
                                "detail_specs": detail_specs
                            }
                            products.append(product_data)
                            
                            # 목표 개수에 도달하면 중단
                            if len(products) >= max_products:
                                break
                    except Exception as e:
                        print(f"  상품 정보 추출 오류: {e}")
                        continue
                
                if len(products) < max_products:
                    print(f"\n⚠️ 유효한 상품이 {len(products)}개만 수집되었습니다. (처리한 상품: {processed_count}개)")
            else:
                print("⚠ 상품 리스트를 찾을 수 없습니다.")
                
        except Exception as e:
            print(f"⚠ 크롤링 오류: {e}")
        
        browser.close()
    
    # 결과 반환
    return {
        "search_keyword": search_keyword,
        "search_url": search_url,
        "total_products": len(products),
        "products": products
    }

# %%
# Cell 4: 실행 및 결과 저장

print("▶ 키워드 기반 상품 검색을 시작합니다...\n")

# 함수의 소스 코드를 가져와서 Python 파일로 저장
function_source = inspect.getsource(crawl_ssadagu_products)

# 실행 스크립트 생성 (함수 + 실행 코드)
script_content = f"""from playwright.sync_api import sync_playwright
import json
import time
import re

# 함수 정의
{function_source}

# 설정값
SEARCH_KEYWORD = {SEARCH_KEYWORD!r}
SEARCH_URL = {search_url!r}

# 함수 실행
if __name__ == "__main__":
    result = crawl_ssadagu_products(
        headless={NOTEBOOK_HEADLESS!r},
        search_url=SEARCH_URL,
        max_products={MAX_PRODUCTS},
        search_keyword=SEARCH_KEYWORD
    )
    
    # JSON 파일로 저장
    output_json = "ssadagu_search_results.json"
    with open(output_json, "w", encoding="utf-8") as f:
        json.dump(result, f, ensure_ascii=False, indent=2)
    
    print(f"\\n✅ 총 {{result['total_products']}}개 상품 정보 수집 완료")
    print(f"✅ JSON 파일 저장 완료: {{output_json}}")
    
    # 결과 미리보기
    print(f"\\n📋 수집된 상품 미리보기 (처음 5개):")
    for idx, product in enumerate(result["products"][:5], 1):
        print(f"\\n  {{idx}}. {{product['title'][:50]}}...")
        print(f"     가격: {{product['price']}}" if product['price'] else "     가격: 정보 없음")
        print(f"     링크: {{product['product_link'][:60]}}..." if product['product_link'] else "     링크: 정보 없음")
        detail_specs = product.get('detail_specs') or {{}}
        if detail_specs:
            preview_items = list(detail_specs.items())[:3]
            for spec_key, spec_val in preview_items:
                print(f"     - {{spec_key}}: {{spec_val}}")
"""

# 임시 파일에 스크립트 저장
fd, script_path = tempfile.mkstemp(suffix="_crawl_ssadagu_products.py", text=True)
os.close(fd)
with open(script_path, "w", encoding="utf-8") as f:
    f.write(script_content)

print(f"📝 생성된 스크립트 파일: {script_path}")
print(f"   (실행 후 자동으로 삭제됩니다)\n")

try:
    # 별도 프로세스에서 실행
    completed = subprocess.run(
        [sys.executable, script_path],
        capture_output=True,
        text=True,
        check=False
    )
    print(completed.stdout)
    if completed.returncode != 0:
        print("--- 프로세스가 에러로 종료되었습니다 (stderr) ---")
        print(completed.stderr)
    else:
        # JSON 파일 읽기
        output_json = "ssadagu_search_results.json"
        if os.path.exists(output_json):
            with open(output_json, "r", encoding="utf-8") as f:
                result = json.load(f)
            print(f"\n✅ 크롤링 완료: 총 {result['total_products']}개 상품 수집")
finally:
    # 임시 파일 삭제
    try:
        os.remove(script_path)
        print(f"\n🗑️ 임시 파일 삭제 완료: {script_path}")
    except Exception as e:
        print(f"\n⚠️ 임시 파일 삭제 실패: {e}")
        print(f"   파일 위치: {script_path}")
# Out:
# ▶ 키워드 기반 상품 검색을 시작합니다...
#
# 📝 생성된 스크립트 파일: C:\ANDROI~1\tmp8_89yisr_crawl_ssadagu_products.py
#    (실행 후 자동으로 삭제됩니다)
# 접속 중: https://ssadagu.kr/shop/search.php?ss_tx=%EC%BB%B4%ED%93%A8%ED%84%B0
#
# 발견된 상품 수: 60개
#
# ✅ 총 30개 상품 정보 수집 완료
# ✅ JSON 파일 저장 완료: ssadagu_search_results.json
#
# 📋 수집된 상품 미리보기 (처음 5개):
#
#   1. 고급형 15.6inch N95 노트북 컴퓨터 국경 간...
#      가격: 329,290원
#      링크: https://ssadagu.kr/shop/view.php?platform=1688&num_iid=89497...
#      - 상표: 아이오파/아이오파
#      - 모델: AP156PC01
#      - 품목 번호: AP156PC01
#
#   2. 16G+512G 태블릿 컴퓨터 패드 프로 풀 네트워크 5G 안드로이드 오피스 엔터테인먼트 ...
#      가격: 98,260원
#      링크: https://ssadagu.kr/shop/view.php?platform=1688&num_iid=89078...
#      - 모델: D23
#      - 품목 번호: D23
#      - 시장 출시 시간: 2025
#
#   3. 데스크탑 컴퓨터 i5i7 게이밍 독립 그래픽 카드 풀세트 가정용 사무용 디자인 13세대 1...
#      가격: 90,950원
#      링크: https://ssadagu.kr/shop/view.php?platform=1688&num_iid=67368...
#      - 상표: 야만적인 작은 악마
#      - 모델: 패키지 1: 호스트 1개 [비즈니스 사무실 및 가정용]
#      - 품목 번호: 009
#
#   4. C 아이디어 안드로이드 태블릿 PC 국경...
#      가격: 47,990원
#      링크: https://ssadagu.kr/shop/view.php?platform=1688&num_iid=89473...
#      - 상표: cidea
#      - 모델: CM516
#      - 운영 체제: ANDROID
#
#   5. 15.6inch 노트북 i7 쿼드 코어 독립 그래픽 게임 사무실 비즈니스 학습 온라인 수업...
#      가격: 191,950원
#      링크: https://ssadagu.kr/shop/view.php?platform=1688&num_iid=53080...
#      - 상표: 다른
#      - 공급 카테고리: 스팟상품
#      - 브랜드 지역: 국내
#
#
# ✅ 크롤링 완료: 총 30개 상품 수집
#
# 🗑️ 임시 파일 삭제 완료: C:\ANDROI~1\tmp8_89yisr_crawl_ssadagu_products.py
